# %%
# Setting up imports, options, and functions to be used later
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.experimental  import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler

ohe = OneHotEncoder(handle_unknown='ignore')
categorical_processing = Pipeline(steps=[('ohe', ohe)])
preprocessing = ColumnTransformer(transformers=[('categorical', categorical_processing, ['conditions'])],
                                  remainder='passthrough')
scaler = MinMaxScaler()
pd.set_option('display.min_rows', 25)

# %%
# Reading and visualizing training data to kick off data exploration

initial_training = pd.read_csv(r'C:\Users\luisp\Downloads\ml-challenge-2023-30412\train.csv')
initial_training
# Out:
#           id    price balcony               conditions  construction_year  \
# 0      10461    60000    True  Buono stato / Abitabile             1980.0
# 1      51304   900000     NaN  Buono stato / Abitabile                NaN
# 2      33032    33000     NaN  Buono stato / Abitabile             1960.0
# 3      62281   166000     NaN   Ottimo / Ristrutturato                NaN
# 4      45681   410000    True  Buono stato / Abitabile                NaN
# 5      59924    89000     NaN  Buono stato / Abitabile                NaN
# 6      36856   632000    True  Buono stato / Abitabile                NaN
# 7      47960   147000    True  Buono stato / Abitabile             1960.0
# 8       7326   275000    True   Ottimo / Ristrutturato             1950.0
# 9      44039   459000    True   Ottimo / Ristrutturato             1995.0
# 10     14881   329000     NaN   Ottimo / Ristrutturato             2011.0
# 11     29022  1050000    True  Buono stato / Abitabile                NaN
# ...      ...      ...     ...                      ...                ...
# 46300  41773   378000    True         Da ristrutturare                NaN
# 46301  46810   208500    True  Buono stato / Abitabile                NaN
# 46302  14128   339000    True         Da ristrutturare             1960.0
# 46303   5026   255000     NaN  Buono stato / Abitabile             1950.0
# 46304  63389   525000    True   Ottimo / Ristrutturato             1930.0
# 46305  44620   285000     NaN         Da ristrutturare             1970.0
# 46306  63289  2260000    True  Buono stato / Abitabile             1950.0
# 46307  33085   329999    True  Buono stato / Abitabile             1929.0
# 46308  17403   599000    True         Da ristrutturare             1920.0
# 46309  33332   549000    True  Buono stato / Abitabile                NaN
# 46310  63367   189000    True  Buono stato / Abitabile             1965.0
# 46311  27322   355000    True   Ottimo / Ristrutturato             1970.0
#
#         latitude  longitude  energy_efficiency  expenses  floor garden  \
# 0      41.901300  12.700000             175.00      30.0    2.0    NaN
# 1      41.907017  12.481311                NaN       NaN    3.0    NaN
# 2      41.976500  12.440500             204.20      30.0    4.0    NaN
# 3      45.484800  12.198200             175.00       NaN    1.0   True
# 4      45.424480  12.328622              65.91       NaN    3.0    NaN
# 5      41.874581  12.541382                NaN       NaN   -1.0    NaN
# 6      41.864600  12.500900             202.39       NaN    2.0    NaN
# 7      45.501742  12.254337                NaN     150.0   -1.0    NaN
# 8      41.896900  12.519100             175.00      60.0    6.0    NaN
# 9      41.906400  12.420300             175.00     100.0    0.0   True
# 10     41.811100  12.613500             175.00     100.0    0.0   True
# 11     45.435364  12.324397             999.00       NaN    2.0    NaN
# ...          ...        ...                ...       ...    ...    ...
# 46300  41.857000  12.559500                NaN     143.0    2.0    NaN
# 46301  41.933699  12.443048                NaN       NaN    4.0    NaN
# 46302  41.931500  12.523500             175.00     105.0    2.0    NaN
# 46303  41.846300  12.483600             175.00      50.0    1.0   True
# 46304  45.480000   9.203200             184.68     115.0    2.0    NaN
# 46305  45.474000   9.108100             269.17     200.0    4.0   True
# 46306  45.470800   9.197000                NaN     580.0    2.0   True
# 46307  41.923500  12.446100             175.00      35.0    3.0    NaN
# 46308  41.916743  12.454925                NaN     170.0    6.0    NaN
# 46309  45.454701   9.242711                NaN       NaN    NaN    NaN
# 46310  45.445605   9.245942                NaN     150.0   -1.0   True
# 46311  41.877000  12.431400             175.00     100.0    1.0    NaN
#
#        n_bathrooms  elevator  total_floors  n_rooms  proximity_to_center  \
# 0              1.0       NaN           3.0      1.0              1.00000
# 1              1.0       1.0           NaN      3.0              1.00000
# 2              1.0       NaN           4.0      1.0              1.00000
# 3              1.0       NaN           1.0      2.0              0.99205
# 4              2.0       1.0           NaN      3.0              1.00000
# 5              1.0       NaN           NaN      2.0              1.00000
# 6              3.0       1.0           5.0      4.0              1.00000
# 7              1.0       1.0           NaN      5.0              1.00000
# 8              1.0       1.0           7.0      3.0              1.00000
# 9              3.0       NaN           2.0      5.0              1.00000
# 10             2.0       NaN           3.0      4.0              1.00000
# 11             2.0       0.0           NaN      5.0              1.00000
# ...            ...       ...           ...      ...                  ...
# 46300          1.0       1.0           7.0      3.0              1.00000
# 46301          1.0       NaN           NaN      2.0              1.00000
# 46302          1.0       1.0           8.0      3.0              1.00000
# 46303          1.0       1.0           5.0      5.0              1.00000
# 46304          1.0       1.0           4.0      3.0              1.00000
# 46305          2.0       1.0           4.0      3.0              1.00000
# 46306          2.0       1.0           6.0      5.0              1.00000
# 46307          1.0       NaN           4.0      3.0              1.00000
# 46308          2.0       1.0           NaN      5.0              1.00000
# 46309          2.0       1.0           NaN      3.0              1.00000
# 46310          1.0       1.0           NaN      3.0              1.00000
# 46311          1.0       1.0           5.0      4.0              1.00000
#
#        surface
# 0         35.0
# 1        131.0
# 2         16.0
# 3        100.0
# 4         90.0
# 5         30.0
# 6          NaN
# 7        107.0
# 8         75.0
# 9        130.0
# 10       129.0
# 11       135.0
# ...        ...
# 46300    125.0
# 46301     67.0
# 46302     90.0
# 46303     92.0
# 46304     86.0
# 46305    127.0
# 46306    180.0
# 46307     88.0
# 46308    189.0
# 46309    140.0
# 46310     70.0
# 46311    101.0
#
# [46312 rows x 17 columns]

# %%
# After getting an initial feel of the dataset, let's get some summary statistics
initial_training.describe()
# Out:
#                  id         price  construction_year      latitude  \
# count  46312.000000  4.631200e+04       32366.000000  46299.000000
# mean   32960.756132  5.031879e+05        1958.032874     43.534743
# std    19090.178152  1.106504e+06          72.021035      1.789416
# min        0.000000  1.540000e+02        1000.000000     41.690300
# 25%    16466.500000  1.990000e+05        1950.000000     41.882400
# 50%    32906.500000  3.150000e+05        1967.000000     41.960604
# 75%    49489.250000  5.150000e+05        1987.000000     45.465800
# max    66159.000000  7.200000e+07        2500.000000     45.561298
#
#           longitude  energy_efficiency       expenses         floor  \
# count  46299.000000       2.640900e+04   30158.000000  44281.000000
# mean      11.451295       5.091382e+03     195.285132      2.033333
# std        1.502453       7.600521e+05    4035.008418      2.175668
# min        9.060775       1.000000e-02       0.000000     -5.000000
# 25%        9.221300       1.590000e+02      40.000000      1.000000
# 50%       12.361864       1.750000e+02      80.000000      2.000000
# 75%       12.487604       1.750000e+02     150.000000      3.000000
# max       12.854100       1.234570e+08  346000.000000     56.000000
#
#         n_bathrooms      elevator  total_floors       n_rooms  \
# count  43896.000000  28869.000000  27963.000000  45959.000000
# mean       1.559140      0.952510      5.724207      3.284166
# std        0.769869      0.212689    191.115233      1.329654
# min        1.000000      0.000000      1.000000      1.000000
# 25%        1.000000      1.000000      3.000000      2.000000
# 50%        1.000000      1.000000      4.000000      3.000000
# 75%        2.000000      1.000000      6.000000      4.000000
# max        9.000000      1.000000  31960.000000      9.000000
#
#        proximity_to_center       surface
# count         46299.000000  45869.000000
# mean              0.994756    114.866620
# std               0.030093     88.650549
# min               0.588014      0.000000
# 25%               1.000000     68.000000
# 50%               1.000000     91.000000
# 75%               1.000000    130.000000
# max               1.000000    990.000000

# %%
# It contains quite a few outliers and a good range of values with different magnitudes
# This already gives us some clues of what clening up and transforming the data will look like
# Let's see how much missing data we have 
initial_training.isna().sum()
# Out:
# id                         0
# price                      0
# balcony                15443
# conditions              1229
# construction_year      13946
# latitude                  13
# longitude                 13
# energy_efficiency      19903
# expenses               16154
# floor                   2031
# garden                 31529
# n_bathrooms             2416
# elevator               17443
# total_floors           18349
# n_rooms                  353
# proximity_to_center       13
# surface                  443
# dtype: int64

# %%
# Garden having over half of the values missing is concerning and must be kept in mind
# The rest of the columns while not perfect don't seem to be too bad
# Thankfully we're not missing any of the prices and very few of the locations (lat, lon)
# Let's check if there are any exact duplicates
initial_training.duplicated().sum()
# Out:
# 0

# %%
# Since price is our target variable, I want to get a good feel of what it looks like from the start
initial_training.sort_values("price")
# Out:
#           id     price balcony                 conditions  construction_year  \
# 4488   39430       154    True  Nuovo / Nuova costruzione             2019.0
# 15605  46741       650     NaN    Buono stato / Abitabile                NaN
# 7132   62599      1000     NaN     Ottimo / Ristrutturato                NaN
# 1123   60369      1000    True     Ottimo / Ristrutturato                NaN
# 8799    9279      1000     NaN                        NaN                NaN
# 35572  65324      1000     NaN     Ottimo / Ristrutturato                NaN
# 25883  19015      1100     NaN     Ottimo / Ristrutturato             1960.0
# 10757  39790      3900     NaN    Buono stato / Abitabile                NaN
# 30519  15179      4000     NaN                        NaN                NaN
# 24062  51110      4500     NaN     Ottimo / Ristrutturato             2010.0
# 27637  36314      4900     NaN    Buono stato / Abitabile             1968.0
# 12690  36012      5000     NaN                        NaN                NaN
# ...      ...       ...     ...                        ...                ...
# 42769  26972  31000000     NaN     Ottimo / Ristrutturato                NaN
# 35207  43140  32000000    True     Ottimo / Ristrutturato             1900.0
# 16873  36410  33000000     NaN                        NaN                NaN
# 41365  10525  35000000     NaN    Buono stato / Abitabile             1960.0
# 19245  16349  35500000     NaN    Buono stato / Abitabile                NaN
# 13368  33796  36000000     NaN                        NaN                NaN
# 15100  62231  39000000     NaN                        NaN                NaN
# 12191  28472  40000000     NaN           Da ristrutturare                NaN
# 15582  31222  45000000     NaN     Ottimo / Ristrutturato                NaN
# 29702  33733  50000000     NaN  Nuovo / Nuova costruzione                NaN
# 29952  43580  62000000     NaN                        NaN                NaN
# 20384  51786  72000000    True     Ottimo / Ristrutturato             1900.0
#
#         latitude  longitude  energy_efficiency  expenses  floor garden  \
# 4488   41.853586  12.652271                NaN       NaN    NaN   True
# 15605  45.476200  12.197400                NaN       0.0    3.0    NaN
# 7132   45.482689  12.250937                NaN       NaN    2.0   True
# 1123   41.735241  12.259580             180.00     100.0    1.0    NaN
# 8799   41.924900  12.489800             175.00       NaN    2.0    NaN
# 35572  45.483269  12.252280             111.00       NaN    0.0   True
# 25883  45.470700   9.236800             118.27     100.0    0.0    NaN
# 10757  45.433700  12.338300                NaN      29.0    1.0    NaN
# 30519  45.462800   9.110040                NaN       0.0    0.0    NaN
# 24062  41.850500  12.438100               3.51       4.0    1.0    NaN
# 27637  45.518100   9.118800                NaN      10.0   -1.0   True
# 12690  41.867000  12.528100                NaN       NaN    8.0    NaN
# ...          ...        ...                ...       ...    ...    ...
# 42769  45.469002   9.168900                NaN       NaN    4.0    NaN
# 35207  41.890900  12.514300             175.00       NaN    0.0    NaN
# 16873  41.957001  12.457900                NaN       NaN    6.0    NaN
# 41365  41.915131  12.383450             175.00       NaN    NaN    NaN
# 19245  45.463699   9.190599                NaN       NaN    NaN    NaN
# 13368  41.906200  12.490000                NaN       NaN    4.0    NaN
# 15100  41.906200  12.490000                NaN       NaN    5.0    NaN
# 12191  45.463200   9.197830                NaN       0.0    NaN    NaN
# 15582  41.882561  12.470400                NaN       NaN    0.0    NaN
# 29702  45.434280  12.338111                NaN       NaN    1.0    NaN
# 29952  45.433701  12.338300                NaN       NaN    6.0    NaN
# 20384  41.890301  12.493500             175.00       NaN    5.0    NaN
#
#        n_bathrooms  elevator  total_floors  n_rooms  proximity_to_center  \
# 4488           2.0       NaN           NaN      5.0             1.000000
# 15605          1.0       NaN           3.0      4.0             1.000000
# 7132           3.0       NaN           NaN      5.0             1.000000
# 1123           1.0       1.0           NaN      3.0             0.793269
# 8799           NaN       NaN           NaN      NaN             1.000000
# 35572          3.0       NaN           2.0      4.0             1.000000
# 25883          1.0       1.0           6.0      2.0             1.000000
# 10757          1.0       NaN           2.0      1.0             1.000000
# 30519          NaN       NaN           NaN      1.0             1.000000
# 24062          NaN       NaN           1.0      NaN             1.000000
# 27637          NaN       1.0           7.0      NaN             0.955790
# 12690          NaN       1.0           8.0      1.0             1.000000
# ...            ...       ...           ...      ...                  ...
# 42769          NaN       1.0           4.0      5.0             1.000000
# 35207          NaN       NaN           5.0      5.0             1.000000
# 16873          NaN       NaN           1.0      NaN             1.000000
# 41365          NaN       NaN           NaN      5.0             1.000000
# 19245          NaN       NaN           NaN      5.0             1.000000
# 13368          NaN       NaN           1.0      NaN             1.000000
# 15100          NaN       NaN           1.0      NaN             1.000000
# 12191          NaN       NaN           NaN      5.0             1.000000
# 15582          NaN       NaN           1.0      5.0             1.000000
# 29702          NaN       NaN           NaN      NaN             1.000000
# 29952          NaN       NaN           1.0      NaN             1.000000
# 20384          NaN       NaN           1.0      5.0             1.000000
#
#        surface
# 4488     119.0
# 15605     80.0
# 7132     190.0
# 1123      60.0
# 8799     150.0
# 35572    190.0
# 25883     60.0
# 10757     40.0
# 30519      NaN
# 24062      NaN
# 27637     12.0
# 12690      NaN
# ...        ...
# 42769      0.0
# 35207    600.0
# 16873     14.0
# 41365    580.0
# 19245     66.0
# 13368      0.0
# 15100    800.0
# 12191      0.0
# 15582     10.0
# 29702      0.0
# 29952    200.0
# 20384      0.0
#
# [46312 rows x 17 columns]

# %%
# This is very useful, let's start by the first few results
# The 154 price initially didn't seem impossible (remember the famous 1€ sicillian homes)
# However, taking a closer look, it is. Being in the outskirts of Rome and supposedly new. This is clearly wrong
# At the opposite end looking up the most expensive "house" it's easy to see it is the Colosseum
# This is the first row that will clearly be removed later
# Looking at the other values though, there are other concerns. 13368 and 15100 have exactly the same coordinates 
# but they have conflicting data. This arouses suspicions of other potential coordinate duplicates. Let's check
initial_training[initial_training.duplicated(["latitude", "longitude"])].sort_values("latitude")
# Out:
#           id    price balcony                 conditions  construction_year  \
# 8267   18071   219000    True     Ottimo / Ristrutturato             1980.0
# 46220  22198    96960     NaN    Buono stato / Abitabile                NaN
# 17830  47861    87000     NaN    Buono stato / Abitabile                NaN
# 26268  33811   121200    True    Buono stato / Abitabile                NaN
# 32139  31727   149000    True     Ottimo / Ristrutturato                NaN
# 43088  48195   790000    True     Ottimo / Ristrutturato                NaN
# 19819  61344   229000    True     Ottimo / Ristrutturato             2007.0
# 27487   8424    65000    True           Da ristrutturare             1980.0
# 31998  13610   639000    True    Buono stato / Abitabile             1980.0
# 41053  64304     9000     NaN    Buono stato / Abitabile                NaN
# 42297  29133   229000    True     Ottimo / Ristrutturato             2005.0
# 8741    7302   100000    True     Ottimo / Ristrutturato                NaN
# ...      ...      ...     ...                        ...                ...
# 6385      70   420000     NaN    Buono stato / Abitabile             1920.0
# 8973   62290   695000    True  Nuovo / Nuova costruzione             1970.0
# 11902  37111   598000     NaN     Ottimo / Ristrutturato                NaN
# 19904  62762   600000     NaN     Ottimo / Ristrutturato                NaN
# 23430  38524   480000    True    Buono stato / Abitabile                NaN
# 26431  41072   475000     NaN    Buono stato / Abitabile                NaN
# 27836  30091  1000000    True           Da ristrutturare             1960.0
# 30429   8259   185000     NaN    Buono stato / Abitabile                NaN
# 34887  17966  1000000    True    Buono stato / Abitabile                NaN
# 35023  60531   250000    True    Buono stato / Abitabile             1970.0
# 43618  13889   450000    True    Buono stato / Abitabile             1965.0
# 46286  58597   749000    True    Buono stato / Abitabile             1922.0
#
#         latitude  longitude  energy_efficiency  expenses  floor garden  \
# 8267   41.716900  12.310100             175.00      40.0    1.0   True
# 46220  41.720993  12.502324                NaN       NaN    NaN    NaN
# 17830  41.720993  12.502324                NaN       NaN   -1.0    NaN
# 26268  41.720993  12.502324                NaN       NaN    1.0    NaN
# 32139  41.722300  12.522400             175.00       0.0    1.0    NaN
# 43088  41.722700  12.501000              22.24       0.0    0.0   True
# 19819  41.723200  12.517000             175.00      50.0    0.0   True
# 27487  41.723200  12.521900             175.00       0.0    0.0    NaN
# 31998  41.723900  12.357000             175.00       0.0    0.0   True
# 41053  41.723900  12.357000             175.00       NaN    1.0    NaN
# 42297  41.723900  12.357000             175.00      80.0    0.0   True
# 8741   41.724600  12.506300             175.00       NaN    2.0    NaN
# ...          ...        ...                ...       ...    ...    ...
# 6385         NaN        NaN                NaN     150.0   -1.0    NaN
# 8973         NaN        NaN                NaN     370.0   -1.0   True
# 11902        NaN        NaN                NaN       NaN    2.0    NaN
# 19904        NaN        NaN                NaN       NaN    2.0   True
# 23430        NaN        NaN                NaN     150.0   -1.0   True
# 26431        NaN        NaN                NaN       NaN   -1.0    NaN
# 27836        NaN        NaN                NaN     300.0   -1.0    NaN
# 30429        NaN        NaN                NaN       NaN    1.0    NaN
# 34887        NaN        NaN                NaN       NaN    2.0   True
# 35023        NaN        NaN                NaN     100.0    6.0   True
# 43618        NaN        NaN                NaN       NaN    2.0    NaN
# 46286        NaN        NaN                NaN       NaN    5.0    NaN
#
#        n_bathrooms  elevator  total_floors  n_rooms  proximity_to_center  \
# 8267           1.0       1.0           6.0      3.0             0.834287
# 46220          1.0       NaN           NaN      4.0             1.000000
# 17830          1.0       NaN           NaN      3.0             1.000000
# 26268          1.0       NaN           NaN      4.0             1.000000
# 32139          2.0       NaN           1.0      3.0             1.000000
# 43088          NaN       NaN           3.0      5.0             1.000000
# 19819          2.0       NaN           1.0      4.0             1.000000
# 27487          1.0       NaN           2.0      2.0             1.000000
# 31998          2.0       NaN           1.0      3.0             0.941552
# 41053          NaN       NaN           1.0      1.0             0.941552
# 42297          2.0       NaN           2.0      4.0             0.941552
# 8741           1.0       1.0           4.0      2.0             1.000000
# ...            ...       ...           ...      ...                  ...
# 6385           1.0       1.0           NaN      2.0                  NaN
# 8973           3.0       1.0           NaN      8.0                  NaN
# 11902          1.0       NaN           NaN      5.0                  NaN
# 19904          2.0       NaN           NaN      5.0                  NaN
# 23430          2.0       1.0           NaN      3.0                  NaN
# 26431          1.0       1.0           NaN      5.0                  NaN
# 27836          2.0       1.0           NaN      6.0                  NaN
# 30429          1.0       NaN           NaN      5.0                  NaN
# 34887          2.0       NaN           NaN      9.0                  NaN
# 35023          1.0       1.0           NaN      3.0                  NaN
# 43618          1.0       1.0           NaN      3.0                  NaN
# 46286          2.0       1.0           NaN      8.0                  NaN
#
#        surface
# 8267      75.0
# 46220     70.0
# 17830    100.0
# 26268    214.0
# 32139     70.0
# 43088    410.0
# 19819    150.0
# 27487     65.0
# 31998    135.0
# 41053     12.0
# 42297     80.0
# 8741      44.0
# ...        ...
# 6385      52.0
# 8973     160.0
# 11902    110.0
# 19904    130.0
# 23430    106.0
# 26431    205.0
# 27836    180.0
# 30429     80.0
# 34887    147.0
# 35023     90.0
# 43618    100.0
# 46286    180.0
#
# [9928 rows x 17 columns]

# %%
# There are a lot and it's easy to see a lot of them have conflicting data
# Since we dont'want to train our model on duplicate and conflicting data, we will drop them right away
# To keep the quality of our data as high as possible I will choose the row with the least missing values to be kept
# Of course, this is a heuristic
# Removing these duplicates is probably the biggest edit we'll make so I'll rename this subset training and clean it as we go
training = initial_training.assign(counts=initial_training.count(axis=1)).sort_values("counts").drop_duplicates(["latitude", "longitude"], keep="last").drop("counts", axis=1)

# %%
training.describe()
# Out:
#                  id         price  construction_year      latitude  \
# count  36384.000000  3.638400e+04       25899.000000  36383.000000
# mean   32936.378710  5.117961e+05        1956.289200     43.578733
# std    19064.823318  1.128026e+06          70.083325      1.792802
# min        0.000000  6.500000e+02        1000.000000     41.690300
# 25%    16436.750000  1.990000e+05        1950.000000     41.882899
# 50%    32862.000000  3.150000e+05        1965.000000     41.973560
# 75%    49389.250000  5.200000e+05        1980.000000     45.467329
# max    66159.000000  7.200000e+07        2500.000000     45.561298
#
#           longitude  energy_efficiency       expenses         floor  \
# count  36383.000000       2.017100e+04   24540.000000  34743.000000
# mean      11.443213       6.622047e+03     203.380929      2.002590
# std        1.503294       8.696716e+05    4070.573225      2.163565
# min        9.060775       1.000000e-02       0.000000     -5.000000
# 25%        9.220600       1.630000e+02      40.000000      1.000000
# 50%       12.356800       1.750000e+02      80.000000      2.000000
# 75%       12.486200       1.750000e+02     150.000000      3.000000
# max       12.854100       1.234570e+08  346000.000000     56.000000
#
#         n_bathrooms      elevator  total_floors       n_rooms  \
# count  34576.000000  22786.000000  20966.000000  36122.000000
# mean       1.568487      0.946897      4.526519      3.318227
# std        0.790175      0.224243      2.647533      1.353425
# min        1.000000      0.000000      1.000000      1.000000
# 25%        1.000000      1.000000      3.000000      2.000000
# 50%        1.000000      1.000000      4.000000      3.000000
# 75%        2.000000      1.000000      6.000000      4.000000
# max        9.000000      1.000000    135.000000      9.000000
#
#        proximity_to_center       surface
# count         36383.000000  36302.000000
# mean              0.994482    116.318330
# std               0.030882     90.244651
# min               0.588014      0.000000
# 25%               1.000000     70.000000
# 50%               1.000000     93.000000
# 75%               1.000000    130.000000
# max               1.000000    990.000000

# %%
# There are some homes that have a surface of 0, let's see how many
zero_surface = training[training["surface"] == 0]
zero_surface
# Out:
#           id     price balcony                 conditions  construction_year  \
# 34101  39141   9900000     NaN    Buono stato / Abitabile                NaN
# 2400   61397   8000000     NaN    Buono stato / Abitabile                NaN
# 37498  57367   1900000     NaN    Buono stato / Abitabile                NaN
# 32284  27873   8900000     NaN           Da ristrutturare                NaN
# 43367   9672  10000000     NaN                        NaN                NaN
# 18286  56220  16000000     NaN     Ottimo / Ristrutturato                NaN
# 35275   1307   8000000     NaN     Ottimo / Ristrutturato                NaN
# 4119    9755  18000000     NaN                        NaN                NaN
# 26693   4445    450000     NaN     Ottimo / Ristrutturato                NaN
# 20408  37603  15000000     NaN           Da ristrutturare                NaN
# 19706  61513   1600000     NaN    Buono stato / Abitabile                NaN
# 43778   4857  16500000     NaN           Da ristrutturare                NaN
# ...      ...       ...     ...                        ...                ...
# 31474  41141    279000    True  Nuovo / Nuova costruzione                NaN
# 13206  35756   1550000    True    Buono stato / Abitabile                NaN
# 33861  24239   1000000    True     Ottimo / Ristrutturato             2003.0
# 5905    4916   2499000     NaN     Ottimo / Ristrutturato             1950.0
# 2811   16261   4500000    True    Buono stato / Abitabile             1960.0
# 32287  23495   4700000    True     Ottimo / Ristrutturato             2020.0
# 41776  43703   1830000    True     Ottimo / Ristrutturato             1970.0
# 569    10175   5900000    True    Buono stato / Abitabile                NaN
# 22073   7968    899000    True           Da ristrutturare             1970.0
# 21226   9939   2000000    True           Da ristrutturare             1970.0
# 16231  49724   4500000    True     Ottimo / Ristrutturato             1960.0
# 15987  30430   1600000    True    Buono stato / Abitabile             1800.0
#
#         latitude  longitude  energy_efficiency  expenses  floor garden  \
# 34101  41.908457  12.478962                NaN       NaN    NaN    NaN
# 2400   41.833338  12.417839                NaN       NaN    NaN    NaN
# 37498  45.438084  12.318196                NaN       NaN    NaN    NaN
# 32284  41.924177  12.521186                NaN       NaN    3.0    NaN
# 43367  45.506401   9.099400                NaN       NaN    6.0    NaN
# 18286  45.480541   9.211150                NaN       NaN    NaN    NaN
# 35275  45.437698  12.336030                NaN       NaN    NaN    NaN
# 4119   45.463699   9.192800                NaN       NaN    4.0    NaN
# 26693  45.474796  12.233891                NaN       NaN    NaN    NaN
# 20408  41.898500  12.490300                NaN       0.0    NaN    NaN
# 19706  45.444176   9.139964                NaN       NaN    NaN    NaN
# 43778  45.454500   9.166240                NaN       0.0    NaN    NaN
# ...          ...        ...                ...       ...    ...    ...
# 31474  41.821130  12.310017             175.00       NaN    2.0   True
# 13206  41.889489  12.403936             175.00       NaN    3.0   True
# 33861  41.849800  12.696600                NaN       0.0    0.0   True
# 5905   41.900500  12.534300             175.00       NaN    0.0   True
# 2811   41.973789  12.464696                NaN    3500.0    1.0   True
# 32287  41.965900  12.607000                NaN       0.0    2.0   True
# 41776  41.995100  12.423500               3.51       0.0    0.0   True
# 569    45.498300   9.201700             159.62       0.0    0.0   True
# 22073  41.841600  12.595600             175.00       0.0    3.0   True
# 21226  41.991100  12.391500               3.51     400.0    0.0   True
# 16231  41.972500  12.488500             175.00    3500.0    0.0   True
# 15987  41.728300  12.507400             175.00       0.0    0.0   True
#
#        n_bathrooms  elevator  total_floors  n_rooms  proximity_to_center  \
# 34101          NaN       NaN           NaN      NaN             1.000000
# 2400           NaN       NaN           NaN      NaN             1.000000
# 37498          NaN       NaN           NaN      NaN             1.000000
# 32284          NaN       NaN           NaN      NaN             1.000000
# 43367          NaN       NaN           1.0      NaN             0.912844
# 18286          NaN       NaN           NaN      5.0             1.000000
# 35275          NaN       NaN           NaN      5.0             1.000000
# 4119           NaN       NaN           1.0      NaN             1.000000
# 26693          NaN       NaN           NaN      5.0             1.000000
# 20408          NaN       NaN           NaN      5.0             1.000000
# 19706          1.0       NaN           NaN      1.0             1.000000
# 43778          NaN       NaN           NaN      5.0             1.000000
# ...            ...       ...           ...      ...                  ...
# 31474          3.0       NaN           NaN      7.0             1.000000
# 13206          7.0       NaN           NaN      6.0             1.000000
# 33861          NaN       NaN           3.0      5.0             1.000000
# 5905           NaN       1.0           5.0      5.0             1.000000
# 2811           8.0       NaN           NaN      3.0             1.000000
# 32287          NaN       1.0           2.0      5.0             1.000000
# 41776          NaN       NaN           2.0      5.0             1.000000
# 569            NaN       1.0           5.0      5.0             1.000000
# 22073          NaN       NaN           3.0      5.0             1.000000
# 21226          NaN       NaN           2.0      5.0             1.000000
# 16231          NaN       NaN           1.0      5.0             1.000000
# 15987          NaN       NaN           2.0      5.0             1.000000
#
#        surface
# 34101      0.0
# 2400       0.0
# 37498      0.0
# 32284      0.0
# 43367      0.0
# 18286      0.0
# 35275      0.0
# 4119       0.0
# 26693      0.0
# 20408      0.0
# 19706      0.0
# 43778      0.0
# ...        ...
# 31474      0.0
# 13206      0.0
# 33861      0.0
# 5905       0.0
# 2811       0.0
# 32287      0.0
# 41776      0.0
# 569        0.0
# 22073      0.0
# 21226      0.0
# 16231      0.0
# 15987      0.0
#
# [89 rows x 17 columns]

# %%
zero_surface.describe()
# Out:
#                  id         price  construction_year   latitude  longitude  \
# count     89.000000  8.900000e+01          25.000000  89.000000  89.000000
# mean   32857.314607  6.662257e+06        1942.600000  43.148747  11.759720
# std    19493.917700  9.679703e+06          68.317275   1.706857   1.352082
# min      567.000000  9.990000e+04        1700.000000  41.728300   9.099400
# 25%    12364.000000  1.600000e+06        1935.000000  41.900500  12.318196
# 50%    35756.000000  3.650000e+06        1960.000000  41.965900  12.417839
# 75%    50732.000000  8.200000e+06        1970.000000  45.443144  12.490300
# max    62697.000000  7.200000e+07        2020.000000  45.525690  12.697700
#
#        energy_efficiency     expenses      floor  n_bathrooms  elevator  \
# count          45.000000    19.000000  67.000000    30.000000       7.0
# mean         1192.541778   389.526316   2.656716     4.633333       1.0
# std          6939.507016  1099.927188   2.402979     2.552664       0.0
# min             1.000000     0.000000  -1.000000     1.000000       1.0
# 25%           175.000000     0.000000   0.000000     3.000000       1.0
# 50%           175.000000     0.000000   3.000000     4.000000       1.0
# 75%           175.000000     0.000000   4.000000     7.000000       1.0
# max         46708.000000  3500.000000  12.000000     9.000000       1.0
#
#        total_floors    n_rooms  proximity_to_center  surface
# count     42.000000  78.000000            89.000000     89.0
# mean       2.928571   4.294872             0.997671      0.0
# std        2.157153   1.859402             0.015646      0.0
# min        1.000000   1.000000             0.879877      0.0
# 25%        1.000000   4.000000             1.000000      0.0
# 50%        2.500000   5.000000             1.000000      0.0
# 75%        4.000000   5.000000             1.000000      0.0
# max       12.000000   9.000000             1.000000      0.0

# %%
# We have two options: imputation and removal
# Imputation when done right can be great, however it is hard to get right and since the subset is small I think it'll be better
# to just remove these rows. Besides that, surface is very highly correlated to price, it is an important column to get right
# Additionally, the mean and median of the subset is an order of magnitude higher, so a simple imputation would likely be inaccurate
# It is also worth noting that this gets rid of the colosseum which is one less pain to take care of
training = training.drop(training[training["surface"] == 0].index)

# %%
# Let's see what the construction year situation looks like 
training.sort_values("construction_year", ascending=False)
# Out:
#           id    price balcony                 conditions  construction_year  \
# 30496   6258   145000     NaN    Buono stato / Abitabile             2500.0
# 17999  35368   520000    True  Nuovo / Nuova costruzione             2025.0
# 7168    4432   226200    True  Nuovo / Nuova costruzione             2025.0
# 10606   6332   730000    True  Nuovo / Nuova costruzione             2025.0
# 27655  24183   440700    True  Nuovo / Nuova costruzione             2025.0
# 2539   18213   274300    True  Nuovo / Nuova costruzione             2024.0
# 14394   7724   266000    True  Nuovo / Nuova costruzione             2024.0
# 12029  32105   250000    True  Nuovo / Nuova costruzione             2024.0
# 32693  42567   740000    True  Nuovo / Nuova costruzione             2024.0
# 940    35608   443000    True  Nuovo / Nuova costruzione             2024.0
# 5446   25052   695000    True  Nuovo / Nuova costruzione             2024.0
# 8191   34232   941000    True  Nuovo / Nuova costruzione             2024.0
# ...      ...      ...     ...                        ...                ...
# 23099   2479   575000    True     Ottimo / Ristrutturato                NaN
# 35144  19434  1500000    True     Ottimo / Ristrutturato                NaN
# 34725  29004   550000    True     Ottimo / Ristrutturato                NaN
# 24740  37954   378000    True    Buono stato / Abitabile                NaN
# 24730   6051   280000    True    Buono stato / Abitabile                NaN
# 24623  42494   115000    True    Buono stato / Abitabile                NaN
# 33709  64883   140000    True    Buono stato / Abitabile                NaN
# 24955  25922   460000    True     Ottimo / Ristrutturato                NaN
# 24880  39801   265000    True    Buono stato / Abitabile                NaN
# 21404  42447   930000    True    Buono stato / Abitabile                NaN
# 21992  62637   524000    True  Nuovo / Nuova costruzione                NaN
# 24497   2478   229000    True     Ottimo / Ristrutturato                NaN
#
#         latitude  longitude  energy_efficiency  expenses  floor garden  \
# 30496  45.497383  12.253994                NaN     200.0    1.0    NaN
# 17999  45.428000   9.202100               3.51     100.0   -1.0   True
# 7168   45.505755   9.244630                NaN       NaN    2.0   True
# 10606  45.510800   9.233700               3.51       NaN    4.0   True
# 27655  45.505800   9.244600             175.00       0.0    2.0   True
# 2539   45.492776   9.209316                NaN       NaN    2.0    NaN
# 14394  45.464005   9.240772                NaN       1.0    1.0   True
# 12029  45.504200   9.127100               3.51       NaN    1.0   True
# 32693  45.457200   9.222000               3.51       NaN    3.0   True
# 940    45.427825   9.202072                NaN     100.0    1.0   True
# 5446   41.923536  12.478871                NaN       NaN    2.0    NaN
# 8191   45.462120   9.209983                NaN       NaN    4.0    NaN
# ...          ...        ...                ...       ...    ...    ...
# 23099  45.491800   9.156300             224.94     390.0   -1.0   True
# 35144  45.482200   9.118600             175.00       1.0    0.0   True
# 34725  45.414600  12.368500             175.00     200.0    0.0   True
# 24740  45.486600   9.164900             170.75     141.0    6.0   True
# 24730  45.498500   9.118600             198.62     240.0    5.0   True
# 24623  41.769300  12.357700             175.00      70.0    4.0   True
# 33709  41.818200  12.615100             175.00      35.0    5.0   True
# 24955  41.900101  12.414700             113.00     150.0    3.0   True
# 24880  41.897600  12.555400             175.00       0.0    5.0   True
# 21404  45.441700   9.183000             217.64     500.0    2.0   True
# 21992  45.494200   9.133660               3.21       1.0    1.0   True
# 24497  41.996500  12.482700             175.00      55.0    2.0   True
#
#        n_bathrooms  elevator  total_floors  n_rooms  proximity_to_center  \
# 30496          1.0       NaN           NaN      6.0                  1.0
# 17999          1.0       1.0           7.0      3.0                  1.0
# 7168           1.0       1.0           NaN      2.0                  1.0
# 10606          3.0       1.0           4.0      4.0                  1.0
# 27655          2.0       1.0           5.0      3.0                  1.0
# 2539           1.0       1.0           NaN      2.0                  1.0
# 14394          1.0       1.0           NaN      2.0                  1.0
# 12029          1.0       1.0           6.0      2.0                  1.0
# 32693          2.0       1.0           7.0      3.0                  1.0
# 940            2.0       1.0           NaN      4.0                  1.0
# 5446           1.0       1.0           NaN      3.0                  1.0
# 8191           2.0       1.0           NaN      3.0                  1.0
# ...            ...       ...           ...      ...                  ...
# 23099          2.0       1.0           5.0      3.0                  1.0
# 35144          3.0       1.0           1.0      5.0                  1.0
# 34725          1.0       1.0           4.0      4.0                  1.0
# 24740          1.0       1.0           8.0      2.0                  1.0
# 24730          1.0       1.0           9.0      4.0                  1.0
# 24623          1.0       1.0           5.0      2.0                  1.0
# 33709          1.0       1.0           5.0      2.0                  1.0
# 24955          1.0       1.0           3.0      4.0                  1.0
# 24880          2.0       1.0           7.0      3.0                  1.0
# 21404          3.0       1.0           3.0      5.0                  1.0
# 21992          2.0       1.0           7.0      3.0                  1.0
# 24497          2.0       1.0           5.0      3.0                  1.0
#
#        surface
# 30496     98.0
# 17999    163.0
# 7168      58.0
# 10606    181.0
# 27655    113.0
# 2539      55.0
# 14394     66.0
# 12029     66.0
# 32693    115.0
# 940      160.0
# 5446     120.0
# 8191     117.0
# ...        ...
# 23099    113.0
# 35144    341.0
# 34725    130.0
# 24740     65.0
# 24730    120.0
# 24623     67.0
# 33709     85.0
# 24955    120.0
# 24880     90.0
# 21404    210.0
# 21992    125.0
# 24497     80.0
#
# [36295 rows x 17 columns]

# %%
# There are a lot of futuristic homes with construction years greater than 2023
# We could explotre this data further, however, construction year should be highly correlated to conditions
# Additionally, it's likely safe to assume that conditions impact a house price's more than the construction year
# Due to this, and the fact that conditions has less missing data, I think it's okay to go with the 
# Minimum Description Length principle and drop the construction column of our training data
# If we wanted to keep the column it is worth noting that precisely because of the correlation to conditions
# a stratified imputation would probably work pretty well

training = training.drop(["construction_year"], axis=1)

# %%
# Onto our next feature that I want to explore: energy_efficiency 
# Let's visualize the variable with a scatter plot
training[training["energy_efficiency"] < 800][["price", "energy_efficiency"]].plot(kind="scatter", x="energy_efficiency", y="price")
# Out:
# <Axes: xlabel='energy_efficiency', ylabel='price'>

# %%
# There are a lot of extremely low values for energy efficiency. A quick google search reveals there's two metrics for it
# It seems as though the majority are reported on the old kWh/m2a unit but there's quite a few that seem to be reported on
# the new EP index value, considering that this is a metric whose adoption should increase overtime, it's likely better to 
# disregard energy efficiency for now as it might lead to a lot of incoveniences later
training[training["energy_efficiency"] < 5].sort_values("energy_efficiency")
# Out:
#           id    price balcony                 conditions   latitude  \
# 14052  22450   190000    True           Da ristrutturare  41.840200
# 31982  13397   615000    True     Ottimo / Ristrutturato  41.839000
# 35263  52075   495000    True    Buono stato / Abitabile  45.433164
# 41221  48840   640000    True  Nuovo / Nuova costruzione  42.019600
# 14915   7006  1430000     NaN    Buono stato / Abitabile  41.985700
# 12117  27796  1850000     NaN    Buono stato / Abitabile  41.991100
# 34066  46056  1490000    True     Ottimo / Ristrutturato  41.927700
# 44416  63447   530000     NaN           Da ristrutturare  41.903600
# 2330   16008  1210000    True    Buono stato / Abitabile  41.927500
# 21828  18186  2400000    True     Ottimo / Ristrutturato  41.924000
# 21561  55670   500000    True           Da ristrutturare  42.007500
# 11800  33462   760000    True     Ottimo / Ristrutturato  41.840700
# ...      ...      ...     ...                        ...        ...
# 44800  21571   308000    True                        NaN  41.857100
# 5779   20342   455000    True     Ottimo / Ristrutturato  45.502400
# 5769   34086   260000    True           Da ristrutturare  41.902900
# 5761    8317   360000    True    Buono stato / Abitabile  41.872600
# 5896   45635   179000    True     Ottimo / Ristrutturato  41.892400
# 22084  19005   695000    True     Ottimo / Ristrutturato  41.948800
# 27615  44106   490000    True    Buono stato / Abitabile  45.458100
# 21877  15613   720000    True     Ottimo / Ristrutturato  45.444400
# 11148  15183   319000    True  Nuovo / Nuova costruzione  45.426600
# 31449   1196   520000     NaN  Nuovo / Nuova costruzione  45.476500
# 25891  44223   395000    True     Ottimo / Ristrutturato  45.504800
# 33154  11589  1475000    True    Buono stato / Abitabile  41.849239
#
#        longitude  energy_efficiency  expenses  floor garden  n_bathrooms  \
# 14052  12.549500               0.01      67.0    2.0    NaN          1.0
# 31982  12.556800               0.01       NaN    0.0   True          3.0
# 35263  12.319764               0.01       NaN    1.0    NaN          2.0
# 41221  12.470700               0.01       NaN    0.0   True          NaN
# 14915  12.421800               0.10     700.0    0.0   True          NaN
# 12117  12.440500               0.10       0.0    0.0    NaN          NaN
# 34066  12.476500               0.10     250.0    4.0    NaN          NaN
# 44416  12.506300               0.10       NaN    3.0    NaN          2.0
# 2330   12.524000               0.10       1.0    3.0    NaN          NaN
# 21828  12.479200               0.10     700.0    3.0    NaN          NaN
# 21561  12.379800               0.10       0.0    0.0   True          3.0
# 11800  12.542300               0.10       NaN    0.0   True          NaN
# ...          ...                ...       ...    ...    ...          ...
# 44800  12.554600               3.51      85.0    5.0    NaN          1.0
# 5779   12.278300               3.51       NaN    0.0   True          2.0
# 5769   12.423300               3.51     100.0    2.0    NaN          1.0
# 5761   12.526700               3.51      64.0    4.0    NaN          1.0
# 5896   12.632300               3.51       1.0    3.0    NaN          2.0
# 22084  12.567400               3.51      75.0    0.0   True          NaN
# 27615   9.214000               3.51     250.0    3.0   True          1.0
# 21877   9.152700               3.52      50.0    1.0   True          2.0
# 11148   9.201900               3.73     140.0    4.0   True          1.0
# 31449   9.171820               3.75     100.0    2.0   True          1.0
# 25891   9.208200               3.75     190.0    4.0   True          1.0
# 33154  12.452190               4.00       0.0    1.0   True          3.0
#
#        elevator  total_floors  n_rooms  proximity_to_center  surface
# 14052       NaN           3.0      2.0                  1.0     65.0
# 31982       1.0           3.0      4.0                  1.0    180.0
# 35263       0.0           NaN      7.0                  1.0    150.0
# 41221       NaN           3.0      5.0                  1.0    387.0
# 14915       1.0           3.0      5.0                  1.0    650.0
# 12117       NaN           1.0      5.0                  1.0    800.0
# 34066       1.0           5.0      5.0                  1.0    275.0
# 44416       1.0           6.0      5.0                  1.0    180.0
# 2330        NaN           4.0      5.0                  1.0    289.0
# 21828       1.0           5.0      5.0                  1.0    345.0
# 21561       NaN           1.0      5.0                  1.0    300.0
# 11800       NaN           2.0      5.0                  1.0    300.0
# ...         ...           ...      ...                  ...      ...
# 44800       1.0           5.0      4.0                  1.0    115.0
# 5779        NaN           1.0      4.0                  1.0    160.0
# 5769        1.0           4.0      3.0                  1.0     90.0
# 5761        1.0           7.0      4.0                  1.0    100.0
# 5896        NaN           4.0      3.0                  1.0     85.0
# 22084       NaN           3.0      5.0                  1.0    222.0
# 27615       1.0           3.0      2.0                  1.0     78.0
# 21877       NaN           2.0      3.0                  1.0    172.0
# 11148       1.0           5.0      2.0                  1.0     75.0
# 31449       NaN           2.0      2.0                  1.0     55.0
# 25891       1.0           6.0      3.0                  1.0     96.0
# 33154       NaN           4.0      5.0                  1.0    535.0
#
# [1884 rows x 16 columns]

# %%
training = training.drop(["energy_efficiency"], axis=1)

# %%
# Let's look at the other column that concerned us: garden
# Garden has over 2/3rds of its values missing which is cause for concern, let's see what it's values looks like
training["garden"].unique()
# Out:
# array([nan, True], dtype=object)

# %%
# Since this is a boolean variable, it is very attractive to assume that, at least for a sizeable proportion of houses,
# NaN indicates the absence of a garden. For now, however, I want to make as little assumptions as possible
# As such I'll drop the column for now and come back to it later to see if this assumption increases our performance
training = training.drop(["garden"], axis=1)

# %%
# There are very few values with latitude and longitude missing, since this is a very important field let's see what they look like
training[training["latitude"].isna()]
# Out:
#           id   price balcony               conditions  latitude  longitude  \
# 35023  60531  250000    True  Buono stato / Abitabile       NaN        NaN
#
#        expenses  floor  n_bathrooms  elevator  total_floors  n_rooms  \
# 35023     100.0    6.0          1.0       1.0           NaN      3.0
#
#        proximity_to_center  surface
# 35023                  NaN     90.0

# %%
# Since it's only one value it's probably safe to remove it
training = training.drop(training[training["latitude"].isna()].index)

# %%
# While a property's floor and the building's number of stories are important for determining the price,
# they are much more helpful to compare apartments within the same building than for comparing different properties
# We can confirm this suspicion with a few scatter plots
training[training["floor"] < 30][["price", "floor"]].plot(kind="scatter", x="floor", y="price")
# Out:
# <Axes: xlabel='floor', ylabel='price'>

# %%
training[training["total_floors"] < 50][["price", "total_floors"]].plot(kind="scatter", x="total_floors", y="price")
# Out:
# <Axes: xlabel='total_floors', ylabel='price'>

# %%
# We can see there is no clear trend that maps an increase in floor or total floors to an increase in price
# Again this is not to say that it is not a factor, rather that it is not that useful for our purpose, I'll drop the columns
training = training.drop(["floor", "total_floors"], axis=1)

# %%
# Let's look again at our missing values
training.isna().sum()
# Out:
# id                         0
# price                      0
# balcony                11814
# conditions               836
# latitude                   0
# longitude                  0
# expenses               11774
# n_bathrooms             1749
# elevator               13516
# n_rooms                  251
# proximity_to_center        0
# surface                   82
# dtype: int64

# %%
# Let's get a feel for the rows with no surface data
training[training["surface"].isna()].sort_values("price")
# Out:
#           id    price balcony                 conditions   latitude  \
# 30519  15179     4000     NaN                        NaN  45.462800
# 24062  51110     4500     NaN     Ottimo / Ristrutturato  41.850500
# 12690  36012     5000     NaN                        NaN  41.867000
# 3656    5192     6000     NaN  Nuovo / Nuova costruzione  41.893000
# 4638    4000    10000     NaN     Ottimo / Ristrutturato  41.938202
# 19715  43610    11000     NaN                        NaN  45.460700
# 21945  65616   116000     NaN           Da ristrutturare  41.901600
# 5676   37411   149000    True     Ottimo / Ristrutturato  41.793400
# 11834  50456   150000    True     Ottimo / Ristrutturato  45.505070
# 25357  50511   165500    True    Buono stato / Abitabile  42.003700
# 25044  40297   166000    True    Buono stato / Abitabile  41.793700
# 29300   1959   171500    True    Buono stato / Abitabile  42.003700
# ...      ...      ...     ...                        ...        ...
# 37837  65652   649000    True    Buono stato / Abitabile  41.933800
# 31059  46938   650000    True    Buono stato / Abitabile  41.947700
# 12503  27433   650000    True    Buono stato / Abitabile  45.504400
# 12990  61776   675000     NaN                        NaN  41.870300
# 6089   18974   684500    True    Buono stato / Abitabile  41.865300
# 31304   6881   817000    True    Buono stato / Abitabile  41.947900
# 2923   64798   857000    True    Buono stato / Abitabile  41.929600
# 8261   62191  2000000     NaN    Buono stato / Abitabile  45.437008
# 45390  64358  2800000     NaN    Buono stato / Abitabile  45.441147
# 31385   6889  3256000     NaN           Da ristrutturare  41.909199
# 2732   15397  3500000     NaN    Buono stato / Abitabile  45.440804
# 45464  41680  7500000     NaN    Buono stato / Abitabile  41.906601
#
#        longitude  expenses  n_bathrooms  elevator  n_rooms  \
# 30519   9.110040       0.0          NaN       NaN      1.0
# 24062  12.438100       4.0          NaN       NaN      NaN
# 12690  12.528100       NaN          NaN       1.0      1.0
# 3656   12.561700       NaN          NaN       1.0      1.0
# 4638   12.374130       1.0          NaN       NaN      NaN
# 19715   9.182120       0.0          NaN       NaN      1.0
# 21945  12.441100       NaN          1.0       1.0      2.0
# 5676   12.490300      75.0          1.0       1.0      2.0
# 11834  12.282380       NaN          1.0       NaN      2.0
# 25357  12.522100       NaN          1.0       NaN      3.0
# 25044  12.490700      75.0          1.0       1.0      2.0
# 29300  12.521900       NaN          1.0       NaN      3.0
# ...          ...       ...          ...       ...      ...
# 37837  12.443100       NaN          2.0       1.0      5.0
# 31059  12.447500       NaN          2.0       NaN      3.0
# 12503  12.276100       NaN          2.0       NaN      5.0
# 12990  12.528000     121.0          NaN       NaN      4.0
# 6089   12.438100       NaN          3.0       1.0      5.0
# 31304  12.447200       NaN          2.0       NaN      3.0
# 2923   12.490600       NaN          2.0       NaN      4.0
# 8261   12.317841       NaN          NaN       NaN      NaN
# 45390  12.335271       NaN          NaN       NaN      4.0
# 31385  12.696700       NaN          NaN       NaN      5.0
# 2732   12.335157       NaN          NaN       NaN      4.0
# 45464  12.481500       NaN          NaN       NaN      NaN
#
#        proximity_to_center  surface
# 30519                  1.0      NaN
# 24062                  1.0      NaN
# 12690                  1.0      NaN
# 3656                   1.0      NaN
# 4638                   1.0      NaN
# 19715                  1.0      NaN
# 21945                  1.0      NaN
# 5676                   1.0      NaN
# 11834                  1.0      NaN
# 25357                  1.0      NaN
# 25044                  1.0      NaN
# 29300                  1.0      NaN
# ...                    ...      ...
# 37837                  1.0      NaN
# 31059                  1.0      NaN
# 12503                  1.0      NaN
# 12990                  1.0      NaN
# 6089                   1.0      NaN
# 31304                  1.0      NaN
# 2923                   1.0      NaN
# 8261                   1.0      NaN
# 45390                  1.0      NaN
# 31385                  1.0      NaN
# 2732                   1.0      NaN
# 45464                  1.0      NaN
#
# [82 rows x 12 columns]

# %%
training[training["surface"].isna()][["price", "id"]].plot(kind="scatter", x="id", y="price")
# Out:
# <Axes: xlabel='id', ylabel='price'>

# %%
training[training["surface"] < 10000][["price", "surface"]].plot(kind="scatter", x="surface", y="price")
# Out:
# <Axes: xlabel='surface', ylabel='price'>

# %%
# For the same reason we dropped those with surface 0, I'll also drop those with missing data for surface
training = training.drop(training[training["surface"].isna()].index)

# %%
# Let's review again how any missing values we have
training.isna().sum()
# Out:
# id                         0
# price                      0
# balcony                11794
# conditions               826
# latitude                   0
# longitude                  0
# expenses               11711
# n_bathrooms             1736
# elevator               13472
# n_rooms                  246
# proximity_to_center        0
# surface                    0
# dtype: int64

# %%
# Let's see what our other variables with many missing values look like
training["balcony"].value_counts()
# Out:
# True    24418
# Name: balcony, dtype: int64

# %%
# I will make the assumption that NaN implies that most likely there is not a balcony and fill them with 0 and replace True with 1
training["balcony"] = training["balcony"].fillna(False)
training["balcony"] = training["balcony"].replace({True: 1, False: 0})

# %%
training["elevator"].value_counts()
# Out:
# 1.0    21530
# 0.0     1210
# Name: elevator, dtype: int64

# %%
training.describe()
# Out:
#                  id         price       balcony      latitude     longitude  \
# count  36212.000000  3.621200e+04  36212.000000  36212.000000  36212.000000
# mean   32938.654783  4.965762e+05      0.674307     43.582619     11.440462
# std    19062.559277  9.774642e+05      0.468640      1.793078      1.504325
# min        0.000000  6.500000e+02      0.000000     41.690300      9.060775
# 25%    16443.250000  1.990000e+05      0.000000     41.882900      9.220389
# 50%    32859.000000  3.150000e+05      1.000000     41.974395     12.356400
# 75%    49389.250000  5.200000e+05      1.000000     45.467403     12.485930
# max    66159.000000  6.200000e+07      1.000000     45.561298     12.854100
#
#             expenses   n_bathrooms      elevator       n_rooms  \
# count   24501.000000  34476.000000  22740.000000  35966.000000
# mean      196.880903      1.565553      0.946790      3.316243
# std      3945.780628      0.782122      0.224457      1.352005
# min         0.000000      1.000000      0.000000      1.000000
# 25%        40.000000      1.000000      1.000000      2.000000
# 50%        80.000000      1.000000      1.000000      3.000000
# 75%       150.000000      2.000000      1.000000      4.000000
# max    346000.000000      9.000000      1.000000      9.000000
#
#        proximity_to_center       surface
# count         36212.000000  36212.000000
# mean              0.994461    116.604938
# std               0.030944     90.171965
# min               0.588014      1.000000
# 25%               1.000000     70.000000
# 50%               1.000000     93.000000
# 75%               1.000000    130.000000
# max               1.000000    990.000000

# %%
training["conditions"].value_counts()
# Out:
# Buono stato / Abitabile      17560
# Ottimo / Ristrutturato        8188
# Nuovo / Nuova costruzione     4913
# Da ristrutturare              4725
# Name: conditions, dtype: int64

# %%
# I will impute the conditions column with the mode
training["conditions"] = training["conditions"].fillna("Buono stato / Abitabile")

# %%
# I will impute the number of bathrooms and rooms with their medians
training["n_bathrooms"] = training["n_bathrooms"].fillna(1)
training["n_rooms"] = training["n_rooms"].fillna(3)

# %%
# I will do the same for the expenses
training["expenses"] = training["expenses"].fillna(80)

# %%
# Elevator is a bit trickier but I will still impute it to the mode
# It wouldn't be unreasonable to assume that the reason it is NaN is because there is no elevator but without more information
# And considering the popularity of elevators, I'd rather impute it with the mode
training["elevator"] = training["elevator"].fillna(1)

# %%
training.isna().sum()
# Out:
# id                     0
# price                  0
# balcony                0
# conditions             0
# latitude               0
# longitude              0
# expenses               0
# n_bathrooms            0
# elevator               0
# n_rooms                0
# proximity_to_center    0
# surface                0
# dtype: int64

# %%
# Let's scale our numeric data
scaled_data = scaler.fit_transform(training[["expenses", "n_rooms", "n_bathrooms", "latitude", "longitude"]])

# %%
training[["expenses", "n_rooms", "n_bathrooms", "latitude", "longitude"]] = scaled_data

# %%
# Let's drop the id
training = training.drop("id", axis=1)

# %%
# Let's drop and separate our target
target = training["price"]
training = training.drop("price", axis=1)

# %%
training = preprocessing.fit_transform(training)

# %%
rf = RandomForestRegressor()

# %%
rf.fit(training, target)
# Out:
# RandomForestRegressor()

# %%
test = pd.read_csv(r'C:\Users\luisp\Downloads\ml-challenge-2023-30412\test_updated.csv')


test_ids = test["id"]

test = test.drop(['construction_year', 'energy_efficiency', 'floor', 'garden',
       'total_floors', 'id'], axis=1)

test['balcony'] = test['balcony'].fillna(False)
test['balcony'] = test['balcony'].replace({True: 1, False: 0}) 

test['conditions'] = test['conditions'].fillna("Buono stato / Abitabile")

test["elevator"] = test["elevator"].fillna(1)

test['n_bathrooms'] = test['n_bathrooms'].fillna(1)
test["n_rooms"] = test["n_rooms"].fillna(3)

test["surface"] = test["surface"].fillna(93)

test["proximity_to_center"] = test["proximity_to_center"].fillna(1)

test["expenses"] = test["expenses"].fillna(80)

test["latitude"] = test["latitude"].fillna(41.974395)
test["longitude"] = test["longitude"].fillna(12.356400)

# %%
test[["expenses", "n_rooms", "n_bathrooms", "latitude", "longitude"]] = scaler.fit_transform(test[["expenses", "n_rooms", "n_bathrooms", "latitude", "longitude"]])

# %%
test = preprocessing.fit_transform(test)

# %%
target_prediction = rf.predict(test)

# %%
target_prediction
# Out:
# array([  99322.55,  260110.  , 1529810.  , ...,  258438.37,  122347.75,
#         171176.47])

# %%
test_prediction = pd.DataFrame(target_prediction, columns=["price"])

# %%
test_prediction["id"] = test_ids

# %%
test_prediction[['id', 'price']]
# Out:
#           id       price
# 0      18825    99322.55
# 1      30956   260110.00
# 2      47193  1529810.00
# 3      27799   416170.00
# 4      22259   166814.00
# 5      42190   178495.10
# 6      50303   396682.50
# 7      34920   297589.75
# 8      58714   305690.00
# 9       4390   467944.94
# 10     13280   228810.00
# 11     25371   167970.00
# ...      ...         ...
# 19776  28540   180659.00
# 19777  18374   312470.00
# 19778  30516   453840.00
# 19779  31430   204625.47
# 19780  16304   127749.50
# 19781   7844   243127.50
# 19782  43102  1176030.00
# 19783  22961   433000.00
# 19784   4606   314910.00
# 19785   6106   258438.37
# 19786  35370   122347.75
# 19787  24890   171176.47
#
# [19788 rows x 2 columns]

# %%
test_prediction.to_csv('first_prediction.csv', sep=',', index=False, encoding='utf-8')
