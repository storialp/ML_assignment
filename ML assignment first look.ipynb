# %%
import pandas as pd

# %%
homes = pd.read_csv(r'C:\Users\luisp\Downloads\ml-challenge-2023-30412\train.csv')

# %%
pd.set_option('display.min_rows', 25)
homes
# Out:
#           id    price balcony               conditions  construction_year  \
# 0      10461    60000    True  Buono stato / Abitabile             1980.0
# 1      51304   900000     NaN  Buono stato / Abitabile                NaN
# 2      33032    33000     NaN  Buono stato / Abitabile             1960.0
# 3      62281   166000     NaN   Ottimo / Ristrutturato                NaN
# 4      45681   410000    True  Buono stato / Abitabile                NaN
# 5      59924    89000     NaN  Buono stato / Abitabile                NaN
# 6      36856   632000    True  Buono stato / Abitabile                NaN
# 7      47960   147000    True  Buono stato / Abitabile             1960.0
# 8       7326   275000    True   Ottimo / Ristrutturato             1950.0
# 9      44039   459000    True   Ottimo / Ristrutturato             1995.0
# 10     14881   329000     NaN   Ottimo / Ristrutturato             2011.0
# 11     29022  1050000    True  Buono stato / Abitabile                NaN
# ...

# %%
homes.columns
# Out:
# Index(['id', 'price', 'balcony', 'conditions', 'construction_year', 'latitude',
#        'longitude', 'energy_efficiency', 'expenses', 'floor', 'garden',
#        'n_bathrooms', 'elevator', 'total_floors', 'n_rooms',
#        'proximity_to_center', 'surface'],
#       dtype='object')

# %%
homes.isna().sum()
# Out:
# id                         0
# price                      0
# balcony                15443
# conditions              1229
# construction_year      13946
# latitude                  13
# longitude                 13
# energy_efficiency      19903
# expenses               16154
# floor                   2031
# garden                 31529
# n_bathrooms             2416
# elevator               17443
# total_floors           18349
# n_rooms                  353
# proximity_to_center       13
# surface                  443
# dtype: int64

# %%
homes.head()
# Out:
#       id   price balcony               conditions  construction_year  \
# 0  10461   60000    True  Buono stato / Abitabile             1980.0
# 1  51304  900000     NaN  Buono stato / Abitabile                NaN
# 2  33032   33000     NaN  Buono stato / Abitabile             1960.0
# 3  62281  166000     NaN   Ottimo / Ristrutturato                NaN
# 4  45681  410000    True  Buono stato / Abitabile                NaN
#
#     latitude  longitude  energy_efficiency  expenses  floor garden  \
# 0  41.901300  12.700000             175.00      30.0    2.0    NaN
# 1  41.907017  12.481311                NaN       NaN    3.0    NaN
# 2  41.976500  12.440500             204.20      30.0    4.0    NaN
# 3  45.484800  12.198200             175.00       NaN    1.0   True
# 4  45.424480  12.328622              65.91       NaN    3.0    NaN
#
#    n_bathrooms  elevator  total_floors  n_rooms  proximity_to_center  surface
# ...

# %%
homes["latitude"]
# Out:
# 0        41.901300
# 1        41.907017
# 2        41.976500
# 3        45.484800
# 4        45.424480
# 5        41.874581
# 6        41.864600
# 7        45.501742
# 8        41.896900
# 9        41.906400
# 10       41.811100
# 11       45.435364
#            ...
# 46300    41.857000
# 46301    41.933699
# 46302    41.931500
# 46303    41.846300
# 46304    45.480000
# 46305    45.474000
# 46306    45.470800
# 46307    41.923500
# 46308    41.916743
# 46309    45.454701
# 46310    45.445605
# 46311    41.877000
# Name: latitude, Length: 46312, dtype: float64

# %%
latitudes_tosort = homes["latitude"]

# %%
sorted_latitudes = latitudes_tosort.sort_values()
sorted_latitudes
# Out:
# 40359    41.690300
# 25462    41.690500
# 25213    41.693920
# 44294    41.694872
# 32557    41.695387
# 3011     41.698299
# 7639     41.714488
# 44500    41.714600
# 1263     41.715200
# 34205    41.715704
# 45976    41.716700
# 4793     41.716900
#            ...
# 6385           NaN
# 8973           NaN
# 11902          NaN
# 19904          NaN
# 23430          NaN
# 26431          NaN
# 27836          NaN
# 30429          NaN
# 34887          NaN
# 35023          NaN
# 43618          NaN
# 46286          NaN
# Name: latitude, Length: 46312, dtype: float64

# %%
homes.describe()
# Out:
#                  id         price  construction_year      latitude  \
# count  46312.000000  4.631200e+04       32366.000000  46299.000000
# mean   32960.756132  5.031879e+05        1958.032874     43.534743
# std    19090.178152  1.106504e+06          72.021035      1.789416
# min        0.000000  1.540000e+02        1000.000000     41.690300
# 25%    16466.500000  1.990000e+05        1950.000000     41.882400
# 50%    32906.500000  3.150000e+05        1967.000000     41.960604
# 75%    49489.250000  5.150000e+05        1987.000000     45.465800
# max    66159.000000  7.200000e+07        2500.000000     45.561298
#
#           longitude  energy_efficiency       expenses         floor  \
# count  46299.000000       2.640900e+04   30158.000000  44281.000000
# mean      11.451295       5.091382e+03     195.285132      2.033333
# std        1.502453       7.600521e+05    4035.008418      2.175668
# min        9.060775       1.000000e-02       0.000000     -5.000000
# ...

# %%
price_sorted_homes = homes["price"].sort_values()
price_sorted_homes
# Out:
# 4488          154
# 15605         650
# 7132         1000
# 1123         1000
# 8799         1000
# 35572        1000
# 25883        1100
# 10757        3900
# 30519        4000
# 24062        4500
# 27637        4900
# 12690        5000
#            ...
# 42769    31000000
# 35207    32000000
# 16873    33000000
# 41365    35000000
# 19245    35500000
# 13368    36000000
# 15100    39000000
# 12191    40000000
# 15582    45000000
# 29702    50000000
# 29952    62000000
# 20384    72000000
# Name: price, Length: 46312, dtype: int64

# %%
homes_sorted_by_value = homes.sort_values("price")
homes_sorted_by_value
#
# Out:
#           id     price balcony                 conditions  construction_year  \
# 4488   39430       154    True  Nuovo / Nuova costruzione             2019.0
# 15605  46741       650     NaN    Buono stato / Abitabile                NaN
# 7132   62599      1000     NaN     Ottimo / Ristrutturato                NaN
# 1123   60369      1000    True     Ottimo / Ristrutturato                NaN
# 8799    9279      1000     NaN                        NaN                NaN
# 35572  65324      1000     NaN     Ottimo / Ristrutturato                NaN
# 25883  19015      1100     NaN     Ottimo / Ristrutturato             1960.0
# 10757  39790      3900     NaN    Buono stato / Abitabile                NaN
# 30519  15179      4000     NaN                        NaN                NaN
# 24062  51110      4500     NaN     Ottimo / Ristrutturato             2010.0
# 27637  36314      4900     NaN    Buono stato / Abitabile             1968.0
# ...

# %%
homes.hist(bins=75, figsize=(50, 25))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'construction_year'}>,
#         <AxesSubplot:title={'center':'latitude'}>],
#        [<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'energy_efficiency'}>,
#         <AxesSubplot:title={'center':'expenses'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'n_bathrooms'}>,
#         <AxesSubplot:title={'center':'elevator'}>,
#         <AxesSubplot:title={'center':'total_floors'}>,
#         <AxesSubplot:title={'center':'n_rooms'}>],
#        [<AxesSubplot:title={'center':'proximity_to_center'}>,
#         <AxesSubplot:title={'center':'surface'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
homes.duplicated(["latitude"]).sum()
# Out:
# 27142

# %%
homes.duplicated(["longitude", "latitude"]).sum()
# Out:
# 9928

# %%
unique_homes = homes.drop_duplicates(["longitude", "latitude"])

# %%
unique_homes
# Out:
#           id    price balcony                 conditions  construction_year  \
# 0      10461    60000    True    Buono stato / Abitabile             1980.0
# 1      51304   900000     NaN    Buono stato / Abitabile                NaN
# 2      33032    33000     NaN    Buono stato / Abitabile             1960.0
# 3      62281   166000     NaN     Ottimo / Ristrutturato                NaN
# 4      45681   410000    True    Buono stato / Abitabile                NaN
# 5      59924    89000     NaN    Buono stato / Abitabile                NaN
# 6      36856   632000    True    Buono stato / Abitabile                NaN
# 7      47960   147000    True    Buono stato / Abitabile             1960.0
# 8       7326   275000    True     Ottimo / Ristrutturato             1950.0
# 9      44039   459000    True     Ottimo / Ristrutturato             1995.0
# 10     14881   329000     NaN     Ottimo / Ristrutturato             2011.0
# ...

# %%
unique_homes_price_sorted = unique_homes.sort_values("price")

# %%
unique_homes_price_sorted
# Out:
#           id     price balcony                 conditions  construction_year  \
# 4488   39430       154    True  Nuovo / Nuova costruzione             2019.0
# 15605  46741       650     NaN    Buono stato / Abitabile                NaN
# 35572  65324      1000     NaN     Ottimo / Ristrutturato                NaN
# 7132   62599      1000     NaN     Ottimo / Ristrutturato                NaN
# 1123   60369      1000    True     Ottimo / Ristrutturato                NaN
# 25883  19015      1100     NaN     Ottimo / Ristrutturato             1960.0
# 30519  15179      4000     NaN                        NaN                NaN
# 24062  51110      4500     NaN     Ottimo / Ristrutturato             2010.0
# 27637  36314      4900     NaN    Buono stato / Abitabile             1968.0
# 12690  36012      5000     NaN                        NaN                NaN
# 1530   30502      6000    True     Ottimo / Ristrutturato                NaN
# ...

# %%
unique_homes.describe()
# Out:
#                  id         price  construction_year      latitude  \
# count  36384.000000  3.638400e+04       25392.000000  36383.000000
# mean   32971.856998  5.116537e+05        1956.350740     43.578733
# std    19073.591103  1.137835e+06          69.967116      1.792802
# min        0.000000  1.540000e+02        1000.000000     41.690300
# 25%    16500.750000  1.990000e+05        1950.000000     41.882899
# 50%    32860.500000  3.150000e+05        1965.000000     41.973560
# 75%    49488.250000  5.200000e+05        1980.000000     45.467329
# max    66159.000000  7.200000e+07        2500.000000     45.561298
#
#           longitude  energy_efficiency       expenses         floor  \
# count  36383.000000       1.989400e+04   24045.000000  34662.000000
# mean      11.443213       6.711243e+03     175.446538      1.995730
# std        1.503294       8.757052e+05    3028.761178      2.168126
# min        9.060775       1.000000e-02       0.000000     -5.000000
# ...

# %%
futuristic_homes = unique_homes[unique_homes["construction_year"]  > 2023]
futuristic_homes
# Out:
#           id    price balcony                 conditions  construction_year  \
# 72     23446  1550600    True  Nuovo / Nuova costruzione             2024.0
# 549    62627   490000    True  Nuovo / Nuova costruzione             2024.0
# 940    35608   443000    True  Nuovo / Nuova costruzione             2024.0
# 1279   25091  3678000    True  Nuovo / Nuova costruzione             2024.0
# 1669   40169   695000    True  Nuovo / Nuova costruzione             2024.0
# 2073   63278  3410000     NaN  Nuovo / Nuova costruzione             2024.0
# 2363   57222   300000    True  Nuovo / Nuova costruzione             2024.0
# 2539   18213   274300    True  Nuovo / Nuova costruzione             2024.0
# 2965   32287   457500    True  Nuovo / Nuova costruzione             2024.0
# 3004   31668   254700    True  Nuovo / Nuova costruzione             2024.0
# 4252   13201   884000    True  Nuovo / Nuova costruzione             2024.0
# ...

# %%
unique_homes.isna().sum()
# Out:
# id                         0
# price                      0
# balcony                12396
# conditions               949
# construction_year      10992
# latitude                   1
# longitude                  1
# energy_efficiency      16490
# expenses               12339
# floor                   1722
# garden                 24878
# n_bathrooms             1943
# elevator               13944
# total_floors           15509
# n_rooms                  281
# proximity_to_center        1
# surface                   93
# dtype: int64

# %%
unique_homes["garden"].sum()
# Out:
# 11506

# %%
unique_homes["garden"].describe()
# Out:
# count     11506
# unique        1
# top        True
# freq      11506
# Name: garden, dtype: object

# %%
unique_homes.hist(bins=75, figsize=(50, 25))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'construction_year'}>,
#         <AxesSubplot:title={'center':'latitude'}>],
#        [<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'energy_efficiency'}>,
#         <AxesSubplot:title={'center':'expenses'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'n_bathrooms'}>,
#         <AxesSubplot:title={'center':'elevator'}>,
#         <AxesSubplot:title={'center':'total_floors'}>,
#         <AxesSubplot:title={'center':'n_rooms'}>],
#        [<AxesSubplot:title={'center':'proximity_to_center'}>,
#         <AxesSubplot:title={'center':'surface'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
unique_homes["energy_efficiency"].value_counts()
# Out:
# 175.00    11488
# 3.51       1658
# 180.00      220
# 1.00        140
# 212.00      135
# 150.00       78
# 170.00       76
# 200.00       74
# 250.00       64
# 160.00       64
# 100.00       58
# 176.00       58
#           ...
# 227.60        1
# 222.48        1
# 98.23         1
# 219.49        1
# 23.65         1
# 130.63        1
# 195.24        1
# 256.89        1
# 172.33        1
# 23.70         1
# 120.57        1
# 269.17        1
# Name: energy_efficiency, Length: 3454, dtype: int64

# %%
unique_homes.describe()
# Out:
#                  id         price  construction_year      latitude  \
# count  36384.000000  3.638400e+04       25392.000000  36383.000000
# mean   32971.856998  5.116537e+05        1956.350740     43.578733
# std    19073.591103  1.137835e+06          69.967116      1.792802
# min        0.000000  1.540000e+02        1000.000000     41.690300
# 25%    16500.750000  1.990000e+05        1950.000000     41.882899
# 50%    32860.500000  3.150000e+05        1965.000000     41.973560
# 75%    49488.250000  5.200000e+05        1980.000000     45.467329
# max    66159.000000  7.200000e+07        2500.000000     45.561298
#
#           longitude  energy_efficiency       expenses         floor  \
# count  36383.000000       1.989400e+04   24045.000000  34662.000000
# mean      11.443213       6.711243e+03     175.446538      1.995730
# std        1.503294       8.757052e+05    3028.761178      2.168126
# min        9.060775       1.000000e-02       0.000000     -5.000000
# ...

# %%
unique_homes.sort_values("expenses")
# Out:
#           id    price balcony                 conditions  construction_year  \
# 18571  11445   157000    True    Buono stato / Abitabile             1965.0
# 4521   25324   249000    True     Ottimo / Ristrutturato                NaN
# 9833   36294    80000     NaN    Buono stato / Abitabile             1940.0
# 41972  14602   290000     NaN           Da ristrutturare             1970.0
# 41971    152  2650000     NaN     Ottimo / Ristrutturato                NaN
# 9830   29210   380000     NaN     Ottimo / Ristrutturato             1800.0
# 9822   13712   265000     NaN           Da ristrutturare                NaN
# 33417   3225     8900     NaN                        NaN                NaN
# 20064   9787   125000    True           Da ristrutturare             1970.0
# 4552   64434   299000    True    Buono stato / Abitabile             1980.0
# 20047  38672   450000    True     Ottimo / Ristrutturato             1960.0
# ...

# %%
expenses_outliers = unique_homes[unique_homes["expenses"] > ((1.5) * 110)]
expenses_outliers
# Out:
#           id    price balcony                 conditions  construction_year  \
# 16     20147   890000     NaN  Nuovo / Nuova costruzione                NaN
# 25     44538   790000    True    Buono stato / Abitabile             1980.0
# 31     46831  1950000    True     Ottimo / Ristrutturato             1890.0
# 32      7586   320000    True           Da ristrutturare             1975.0
# 34     50424   790000     NaN    Buono stato / Abitabile             1900.0
# 37      3182  1150000    True    Buono stato / Abitabile             1967.0
# 39     11827    49000     NaN           Da ristrutturare                NaN
# 46     11043   368000    True    Buono stato / Abitabile             1980.0
# 47      4317  2050000    True    Buono stato / Abitabile             1955.0
# 48     18708   235000    True    Buono stato / Abitabile             1970.0
# 54      4975   248000    True     Ottimo / Ristrutturato             1960.0
# ...

# %%
expenses_outliers[["id", "expenses"]].plot(kind="scatter", x="id", y="expenses")
# Out:
# <AxesSubplot:xlabel='id', ylabel='expenses'>

# %%
expenses_outliers.sort_values("expenses")
# Out:
#           id    price balcony                 conditions  construction_year  \
# 44623  35569   315000    True    Buono stato / Abitabile             1970.0
# 44728   9403   450000     NaN  Nuovo / Nuova costruzione             1960.0
# 25789  58919   730000    True  Nuovo / Nuova costruzione             1900.0
# 19949  27544   340000    True    Buono stato / Abitabile             1960.0
# 3193   17261   660000    True    Buono stato / Abitabile             2004.0
# 20850  36112   285000     NaN    Buono stato / Abitabile             1970.0
# 14744  58360   299000    True           Da ristrutturare             1930.0
# 13196  60693   465000    True  Nuovo / Nuova costruzione             1970.0
# 13182  23021   480000    True     Ottimo / Ristrutturato             1930.0
# 30040   2333    84000    True           Da ristrutturare             1960.0
# 26776  57427   320000    True    Buono stato / Abitabile             1958.0
# ...

# %%
unique_homes.describe()
# Out:
#                  id         price  construction_year      latitude  \
# count  36384.000000  3.638400e+04       25392.000000  36383.000000
# mean   32971.856998  5.116537e+05        1956.350740     43.578733
# std    19073.591103  1.137835e+06          69.967116      1.792802
# min        0.000000  1.540000e+02        1000.000000     41.690300
# 25%    16500.750000  1.990000e+05        1950.000000     41.882899
# 50%    32860.500000  3.150000e+05        1965.000000     41.973560
# 75%    49488.250000  5.200000e+05        1980.000000     45.467329
# max    66159.000000  7.200000e+07        2500.000000     45.561298
#
#           longitude  energy_efficiency       expenses         floor  \
# count  36383.000000       1.989400e+04   24045.000000  34662.000000
# mean      11.443213       6.711243e+03     175.446538      1.995730
# std        1.503294       8.757052e+05    3028.761178      2.168126
# min        9.060775       1.000000e-02       0.000000     -5.000000
# ...

# %%
unique_homes.sort_values("energy_efficiency")
# Out:
#           id    price balcony                 conditions  construction_year  \
# 31982  13397   615000    True     Ottimo / Ristrutturato             2006.0
# 35263  52075   495000    True    Buono stato / Abitabile                NaN
# 41221  48840   640000    True  Nuovo / Nuova costruzione             2015.0
# 14052  22450   190000    True           Da ristrutturare             1965.0
# 2330   16008  1210000    True    Buono stato / Abitabile             1920.0
# 21828  18186  2400000    True     Ottimo / Ristrutturato             1960.0
# 7253   37186  1179000    True           Da ristrutturare             1960.0
# 31566  25967   440000     NaN    Buono stato / Abitabile             1965.0
# 34066  46056  1490000    True     Ottimo / Ristrutturato             1900.0
# 44416  63447   530000     NaN           Da ristrutturare             1920.0
# 18212  48102  1300000     NaN     Ottimo / Ristrutturato             1800.0
# ...

# %%
unique_homes_efficiency = unique_homes[unique_homes["energy_efficiency"].notna()]

# %%
unique_homes_efficiency.sort_values("energy_efficiency")
# Out:
#           id     price balcony                 conditions  construction_year  \
# 31982  13397    615000    True     Ottimo / Ristrutturato             2006.0
# 35263  52075    495000    True    Buono stato / Abitabile                NaN
# 41221  48840    640000    True  Nuovo / Nuova costruzione             2015.0
# 14052  22450    190000    True           Da ristrutturare             1965.0
# 2330   16008   1210000    True    Buono stato / Abitabile             1920.0
# 21828  18186   2400000    True     Ottimo / Ristrutturato             1960.0
# 7253   37186   1179000    True           Da ristrutturare             1960.0
# 31566  25967    440000     NaN    Buono stato / Abitabile             1965.0
# 34066  46056   1490000    True     Ottimo / Ristrutturato             1900.0
# 44416  63447    530000     NaN           Da ristrutturare             1920.0
# 18212  48102   1300000     NaN     Ottimo / Ristrutturato             1800.0
# ...

# %%
conditions_series = unique_homes["conditions"]
conditions_series.describe()
# Out:
# count                       35435
# unique                          4
# top       Buono stato / Abitabile
# freq                        17725
# Name: conditions, dtype: object

# %%
conditions_series.unique()
# Out:
# array(['Buono stato / Abitabile', 'Ottimo / Ristrutturato',
#        'Da ristrutturare', 'Nuovo / Nuova costruzione', nan], dtype=object)

# %%
# assigning 0 to NaN, 1 to Da ristrutturare, 2 to buono, 3 to ottimo and 4 to nuovo

transformed_homes = unique_homes.fillna(columns=["conditions"],value=0)
transformed_homes.replace(['Buono stato / Abitabile', 'Ottimo / Ristrutturato',
       'Da ristrutturare', 'Nuovo / Nuova costruzione'], [2, 3, 1, 4])
transformed_homes.sort_values("conditions")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14292\2052540458.py in <module>
#       1 # assigning 0 to NaN, 1 to Da ristrutturare, 2 to buono, 3 to ottimo and 4 to nuovo
#       2
# ----> 3 transformed_homes = unique_homes.fillna(columns=["conditions"],value=0)
#       4 transformed_homes.replace(['Buono stato / Abitabile', 'Ottimo / Ristrutturato',
#       5        'Da ristrutturare', 'Nuovo / Nuova costruzione'], [2, 3, 1, 4], inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: fillna() got an unexpected keyword argument 'columns'
